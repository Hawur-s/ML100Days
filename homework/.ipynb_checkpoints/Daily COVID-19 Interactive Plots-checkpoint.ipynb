# %%
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen
import pandas as pd
import numpy as np
from datetime import date, datetime
import matplotlib.pyplot as plt
import gc #garbage collector
import plotly.graph_objects as go
import plotly.offline as py
py.init_notebook_mode(connected=True)
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fname = 'https://www.worldometers.info/coronavirus/#countries'
req = Request(fname, headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req)
page_soup = soup(webpage, "html.parser")
today = datetime.now()
today_str = "%s %d, %d" % (date.today().strftime("%b"), today.day, today.year)
yesterday_str = "%s %d, %d" % (date.today().strftime("%b"), today.day-1, today.year)
clean = True

# %%
print("This version of the notebook is being run on %s." % today_str)
# Out:
# This version of the notebook is being run on Mar 11, 2021.

# %%
table = page_soup.findAll("table", {"id": "main_table_countries_yesterday"})
containers = table[0].findAll("tr", {"style": ""})
del containers[0]

all_data = []
for country in containers:
    country_data = []
    country_container = country.findAll("td")
    if country_container[1].text == 'China':
        continue
    for i in range(1, len(country_container)):
        final_feature = country_container[i].text
        if clean:
            if i != 1 and i != len(country_container)-1:
                final_feature = final_feature.replace(',', '')
                if final_feature.find('+') != -1:
                    final_feature = final_feature.replace('+', '')
                    final_feature = float(final_feature)
                elif final_feature.find('-') != -1:
                    final_feature = final_feature.replace('-', '')
                    final_feature = float(final_feature)*-1
        if final_feature == 'N/A':
            final_feature = 0
        elif final_feature == '' or final_feature == ' ':
            final_feature = -1 #None
        country_data.append(final_feature)
    all_data.append(country_data)

# %%
df = pd.DataFrame(all_data)
df = df.drop([15, 16, 17], axis=1) # Get rid of unnecessary data

# %%
column_labels = ["Country", "Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical",
                "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population", "Continent"]
df.columns = column_labels

# %%
country_labels = page_soup.findAll("a", {"class": "mt_a"})
c_label = []
for country in country_labels:
    c_label.append(country.text)
c_label = set(c_label)

not_counted = []
sorted_countries = set(df['Country']) #Increase computational speed
for country in c_label:
    if country not in sorted_countries:
        not_counted.append(country)

# %%
print(not_counted + ['China'])
# Out:
# ['Micronesia', 'Marshall Islands', 'Saint Pierre Miquelon', 'China', 'Falkland Islands', 'Anguilla', 'Tajikistan', 'Saint Kitts and Nevis', 'Grenada', 'Greenland', 'China']

# %%
for label in df.columns:
    if label != 'Country' and label != 'Continent':
        df[label] = pd.to_numeric(df[label])

# %%
df['%Inc Cases'] = df['New Cases']/df['Total Cases']*100
df['%Inc Deaths'] = df['New Deaths']/df['Total Deaths']*100
df['%Inc Recovered'] = df['New Recovered']/df['Total Recovered']*100

# %%
pd.options.display.max_rows = None
df
# Out:
#                     Country  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0                     World    118621421   461464.0       2631396     10042.0
# 1                       USA     29862124    60355.0        542191      1610.0
# 2                     India     11284311    22841.0        158213       134.0
# 3                    Brazil     11205972    80955.0        270917      2349.0
# 4                    Russia      4351553     9079.0         90275       466.0
# 5                        UK      4234924     5926.0        124987       190.0
# 6                    France      3963165    30303.0         89565       264.0
# 7                     Spain      3178442     6672.0         71961       234.0
# 8                     Italy      3123368    22409.0        100811       332.0
# 9                    Turkey      2821943    14556.0         29227        67.0
# 10                  Germany      2532855    12246.0         73276       295.0
# 11                 Colombia      2285960     3588.0         60773        97.0
# 12                Argentina      2169694     7693.0         53359       107.0
# 13                   Mexico      2137884     7407.0        191789       866.0
# 14                   Poland      1828313    17260.0         45997       398.0
# 15                     Iran      1715162     8603.0         60928        61.0
# 162      North America    0.989597     2.127660        3.412144
# 163             Africa    0.152749    -1.265823        1.011195
# 164             Africa    0.138466    -0.684932       -0.029180
# 165               Asia    3.131284   -33.333333        1.144083
# 166      North America    0.596481    -2.702703        2.898068
# 167             Africa    0.240457     3.921569        0.370920
# 168             Africa   -0.032982    -6.666667       -0.035600
# 169             Africa    1.472557   -14.285714        4.018913
# 170               Asia    1.560716     1.059002        0.068871
# 171             Europe   -0.038551    -1.818182       -0.039698
# 172               Asia    0.118624    -2.857143       -0.049900
# 173  Australia/Oceania    0.041494    -3.846154       -0.043403
# 174             Africa    1.266357   -33.333333       -0.129366
# 175      North America    0.593607    -6.666667        2.462578
# 176      North America    0.048146    -3.703704        0.147493
# 177             Europe    0.678952    -3.846154        0.320000
# 178             Africa   -0.049358    -1.176471       -0.052687
# 179             Africa    1.641791    -3.125000        2.771226
# 180  Australia/Oceania    4.078116    23.809524       -0.118203
# 181      North America    0.419162   -12.500000        0.632340
# 182      North America   -0.063654    -8.333333       -0.071480
# 183               Asia    5.693950   100.000000        2.003643
# 184             Europe    7.212476    -4.000000       -0.239808
# 185               Asia    0.102249   -10.000000        0.427350
# 186      North America    2.267574     4.347826        6.952965
# 187               Asia   -0.115207  -100.000000       -0.115473
# 188      North America    0.957592    -8.333333       -0.144928
# 189             Europe   -0.151515  -100.000000       -0.152207
# 190             Africa   -0.156006   -10.000000       -0.170068
# 191      North America   -0.156740  -100.000000       -0.216450
# 192      North America    5.627010    16.666667        3.617021
# 193             Africa   -0.196464    -4.761905       -0.546448
# 194      North America   -0.217391   -50.000000        0.930233
# 195               Asia    0.520833   -33.333333       -0.546448
# 196      North America   -0.653595  -100.000000       -0.763359
# 197      North America   -0.662252   100.000000       -0.724638
# 198               Asia    2.068966   100.000000       -1.063830
# 199  Australia/Oceania    5.405405   100.000000       -1.724138
# 200  Australia/Oceania   -1.515152   -50.000000       -1.754386
# 201  Australia/Oceania   71.212121   100.000000      -14.285714
# 202               Asia   -2.083333   100.000000       -2.127660
# 203               Asia   -2.127660   100.000000       -2.380952
# 204             Europe   -3.703704   100.000000       -6.666667
# 205      North America   -5.000000  -100.000000       -7.142857
# 206  Australia/Oceania   -5.555556   100.000000       12.500000
# 207             Africa  -10.000000  -100.000000      -12.500000
# 208  Australia/Oceania  -33.333333   100.000000      -50.000000
# 209  Australia/Oceania  -33.333333   100.000000     -100.000000
# 210                All    0.389022     0.381623        0.404035

# %%
EXPORT = True
today = datetime.now()
if EXPORT:
    today = date.today()
    df.to_csv(f'covid_stats_{today.year}_{today.month}_{today.day-1}')
    print("Dataset is %.2f MB" % (df.memory_usage(deep=True).sum()/1000000))
# Out:
# Dataset is 0.05 MB

# %%
cases_df = df[["Total Recovered", "Active Cases", "Total Deaths"]].loc[0]
pd.DataFrame(cases_df).T.plot.bar(stacked=True, figsize=(16, 12))
plt.xticks(np.arange(0, 0, 1)) # No Ticks
plt.title(f"Total Number of Cases, Recoveries, and Deaths on {yesterday_str}", fontsize=20)
plt.legend(prop={"size": 12})

prev = 0
total = cases_df.sum()
for num in cases_df.cumsum():
    val = round((num-prev)/total*100, 3)
    plt.annotate(f"{val}% ({num-prev})", (0, (num-prev)/2+prev), fontsize=14, ha='center')
    prev = num
plt.show()

# %%
new_df = df[["New Cases", "New Recovered", "New Deaths"]].loc[0]
pd.DataFrame(new_df).T.plot.bar(stacked=True, figsize=(16, 12))
plt.xticks(np.arange(0, 0, 1)) # No Ticks
plt.title(f"New Cases, Recoveries, and Deaths on {yesterday_str}", fontsize=20)
plt.legend(prop={"size": 12})

prev = 0
total = new_df.sum()
for num in new_df.cumsum():
    val = round((num-prev)/total*100, 3)
    plt.annotate(f"{val}% ({round(num-prev)})", (0, (num-prev)/2+prev), fontsize=14, ha='center')
    prev = num
plt.show()

# %%
pinc_df = df[["%Inc Cases", "%Inc Recovered", "%Inc Deaths"]].loc[0]
pd.DataFrame(pinc_df).T.plot.bar(figsize=(16, 12))
plt.xticks(np.arange(0, 0, 1)) # No Ticks
plt.title(f"Percentage Increase in Cases, Recoveries, and Deaths on {yesterday_str}", fontsize=20)
plt.ylabel("Percentage", fontsize=14)
plt.legend(prop={"size": 12})
plt.show()

# %%
continent_df = df.groupby('Continent').sum().drop('All')
continent_df = continent_df.reset_index()
continent_df
# Out:
#            Continent  Total Cases  New Cases  Total Deaths  New Deaths  \
# 0             Africa      4022108    10420.0        106883       265.0
# 1               Asia     25697413    89505.0        401917       782.0
# 2  Australia/Oceania        51964      146.0          1094        -4.0
# 3             Europe     35562417   176688.0        844826      3511.0
# 4      North America     34295239    75423.0        783451      2566.0
# 5      South America     18887923   109236.0        488472      2823.0
#
#    Total Recovered  New Recovered  Active Cases  Serious/Critical  \
# 0          3589011        10595.0        326214              2570
# 1         24080460        70618.0       1215032             22375
# 2            34342           -1.0         16523                -5
# 3         25104214       104066.0       7807046             26584
# 4         24320297       102373.0       9191490             19146
# 5         16995034        93060.0       1404417             19054
#
#    Tot Cases/1M  Deaths/1M  Total Tests  Tests/1M  Population  %Inc Cases  \
# 0      349422.0     5665.5     35164616   3414441  1362519925   16.341006
# 1      885278.0     8984.7    491175356  36940567  3183815916   23.110930
# 2       73759.0      539.0     16665483   1266334    42459910    7.120115
# 3     2731664.0    52519.0    540617291  49108924   747942743   31.670223
# 4      854416.0    12755.0    414474003  15243801   592043088   16.754038
# 5      399727.0     9648.0     73077474   2608718   433203140    6.706429
#
#    %Inc Deaths  %Inc Recovered
# 0  -168.919975       32.574772
# 1   224.861051       10.354936
# 2   469.144139     -155.427419
# 3     1.909376        9.243483
# 4  -275.810107       16.165389
# 5     3.267187        4.997751

# %%
cases_vis_list = ['Total Cases', 'Active Cases', 'New Cases', 'Serious/Critical', 'Tot Cases/1M']
deaths_vis_list = ['Total Deaths', 'New Deaths', 'Deaths/1M']
recovered_vis_list = ['Total Recovered', 'New Recovered']
tests_vis_list = ['Total Tests', 'Tests/1M']
essentials = [['Total Cases', 'Active Cases', 'New Cases'], ['Total Deaths', 'New Deaths'], ['Total Recovered', 'New Recovered']]

# %%
def continent_visualization(vis_list):
    for label in vis_list:
        pd.DataFrame(continent_df[label]).T.plot.bar(stacked=True, figsize=(16, 12))
        plt.title(f"{label} at the end of {yesterday_str}", fontsize=24)
        plt.xlabel("")
        plt.ylabel(f"{label}", fontsize=16)
        plt.yticks(fontsize=16)
        plt.legend(continent_df['Continent'])

        prev = 0
        total = continent_df[label].sum()
        for num in continent_df[label].cumsum():
            val = round((num-prev)/total*100, 3)
            if val < 1:
                continue
            plt.annotate(f"{val}% ({round(num-prev)})", (0, (num-prev)/2+prev), fontsize=14, ha='center')
            prev = num

        plt.show()
        gc.collect()

# %%
continent_visualization(cases_vis_list)

# %%
continent_visualization(deaths_vis_list)

# %%
continent_visualization(tests_vis_list)

# %%
def continent_visualization2(index, label):
    continent_df.plot.bar(x="Continent", y=essentials[index], stacked=True, figsize=(16, 12))
    plt.title(f"{label} at the end of {yesterday_str}", fontsize=24)
    plt.xlabel("")
    plt.ylabel(f"{label}", fontsize=16)
    plt.yticks(fontsize=16)
    plt.show()
    gc.collect()

# %%
continent_visualization2(0, "Total Cases")

# %%
continent_visualization2(1, "Total Deaths")

# %%
continent_visualization2(2, "Total Recoveries")

# %%
df = df.drop([len(df)-1])
country_df = df.drop([0])

# %%
country_l = country_df.columns[1:14]

fig = go.Figure()
c = 0
for i in country_df.index:
    if c<4:
        fig.add_trace(go.Bar(name=country_df['Country'][i], x=country_l, y=country_df.loc[i][1:14]))
    else:
        break
    c += 1
    
fig.update_layout(title={'text': '4 Countries with Most COVID Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", yaxis_type="log", xaxis_tickangle=-90)
fig.show()
# Out:
# <div>                            <div id="541bc9a6-aa75-45a0-8e3e-98c5a08e5dfb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("541bc9a6-aa75-45a0-8e3e-98c5a08e5dfb")) {                    Plotly.newPlot(                        "541bc9a6-aa75-45a0-8e3e-98c5a08e5dfb",                        [{"name": "USA", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [29801506, 55683.0, 540574, 1704.0, 20549678, 99762.0, 8711254.0, 12715, 89673.0, 1627.0, 371894718, 1119032, 332336197]}, {"name": "India", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [11261470, 16846.0, 158079, 113.0, 10917624, 20138.0, 185767.0, 8944, 8106.0, 114.0, 222716796, 160308, 1389308662]}, {"name": "Brazil", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [11125017, 69537.0, 268568, 1954.0, 9843218, 60898.0, 1013231.0, 8318, 52084.0, 1257.0, 28600000, 133897, 213596922]}, {"name": "Russia", "type": "bar", "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [4342474, 9445.0, 89809, 336.0, 3932177, 9931.0, 320488.0, 2300, 29748.0, 615.0, 113700000, 778887, 145977558]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidt ...

# %%
inc_l = country_df.columns[15:]
inc_df = country_df.sort_values("%Inc Cases", ascending=False)
fig = go.Figure()
c = 0
for i in inc_df.index:
    if i > 50:
        continue
    if c < 4:
        fig.add_trace(go.Bar(name=country_df['Country'][i], x=inc_l, y=inc_df.loc[i][15:]))
    else:
        break
    c += 1
    
fig.update_layout(title={'text': '4 Countries with Highest Increase in COVID Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_title="Percentage", xaxis_tickangle=0)
fig.show()
# Out:
# <div>                            <div id="c37427b0-2bce-4a7b-9d1e-d92ad60b29c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c37427b0-2bce-4a7b-9d1e-d92ad60b29c3")) {                    Plotly.newPlot(                        "c37427b0-2bce-4a7b-9d1e-d92ad60b29c3",                        [{"name": "Jordan", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [1.5992691123061404, 1.1692429647245344, 1.071700605628026]}, {"name": "Hungary", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [1.3665623612446787, 0.9785705437879352, 0.6496610079481687]}, {"name": "Bulgaria", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [1.312569104776897, 1.2658227848101267, 1.5644682279167699]}, {"name": "Lebanon", "type": "bar", "x": ["%Inc Cases", "%Inc Deaths", "%Inc Recovered"], "y": [0.9802750444222127, 0.876509544215037, 0.646794776083842]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f92 ...

# %%
country_labels = country_df.columns[1:14]

def country_visualization(continent):
    buttons_list = []
    base_list = [False for i in range(len(country_df))]
    c = 0
    for i in country_df.index:
        if country_df.loc[i]['Continent'] != continent:
            continue
        tmp_list = base_list.copy()
        tmp_list[c] = True
        c += 1
        buttons_list.append(dict(
                    args=[{"visible": tmp_list}],
                    label=country_df.loc[i]['Country'],
                    method="update"
                ))


    fig = go.Figure()
    c = 0
    for i in country_df.index:
        if country_df.loc[i]['Continent'] != continent:
            continue
        fig.add_trace(go.Bar(name=country_df.loc[i]['Country'], x=country_labels, y=country_df.loc[i][1:14], visible=False if c != 0 else True))
        c += 1
        
    fig.update_layout(
        updatemenus=[
            dict(
                buttons=buttons_list,
                direction="down",
                pad={"r": 10, "t": 10},
                showactive=True,
                x=0.1,
                xanchor="left",
                y=1.1,
                yanchor="top"
            ),
        ]
    )

    fig.update_layout(title={'text': '%s COVID-19 Cases Search on %s' % (continent, yesterday_str), 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_type="log", xaxis_tickangle=-90)
    fig.show()

# %%
country_visualization('Africa')
# Out:
# <div>                            <div id="d9e77e6b-25fb-4769-9364-4e41b2e81b44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9e77e6b-25fb-4769-9364-4e41b2e81b44")) {                    Plotly.newPlot(                        "d9e77e6b-25fb-4769-9364-4e41b2e81b44",                        [{"name": "South Africa", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1522697, 991.0, 50906, 103.0, 1444282, 2237.0, 27509.0, 546, 25454.0, 851.0, 9299884, 155462, 59820794]}, {"name": "Morocco", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [486833, 508.0, 8695, 12.0, 473208, 664.0, 4930.0, 272, 13083.0, 234.0, 5743512, 154353, 37210287]}, {"name": "Tunisia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [238613, 596.0, 8268, 43.0, 205176, 2182.0, 25169.0, 273, 20046.0, 695.0, 1011915, 85011, 11903400]}, {"name": "Egypt", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [187716, 622.0, 11082, 44.0, 144917, 432.0, 31717.0, 90, 1811.0, 107.0, 1000000, 9648, 103652051]}, {"name": "Ethiopia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [168335, 1202.0, 2451, 9.0, 139532, 893.0, 26352.0, 427, 1440.0, 21.0, 2192311, 18753, 116901593]}, {"name": "Nigeria", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [159252, 346.0, 1988, 6.0, 139056, 554.0, 18208.0, 10, 760.0, 9.0, 1601396, 7640, 209616674]}, {"name": "Libya", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [140688, 1030.0, 2297, 9.0, 128002, 1124.0, 10389.0, -1, 20286.0, 331.0, 762485, 109943, 6935250]}, {"name": "Algeria", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [114543, 161.0, 3022, 4.0, 79319, 132.0, 32202.0, 19, 2580.0, 68.0, -1, -1, 44391836]}, {"name": "Kenya", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [109643, 479.0, 1886, 7.0, 87736, 113.0, 20021.0, 86, 2009.0, 35.0, 1340657, 24564, 54578543]}, {"name": "Ghana", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Case ...

# %%
country_visualization('Asia')
# Out:
# <div>                            <div id="c7fd2968-f650-421f-bbd9-8a3e52da800e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7fd2968-f650-421f-bbd9-8a3e52da800e")) {                    Plotly.newPlot(                        "c7fd2968-f650-421f-bbd9-8a3e52da800e",                        [{"name": "India", "type": "bar", "visible": true, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [11261470, 16846.0, 158079, 113.0, 10917624, 20138.0, 185767.0, 8944, 8106.0, 114.0, 222716796, 160308, 1389308662]}, {"name": "Turkey", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [2807387, 13755.0, 29160, 66.0, 2640669, 8639.0, 137558.0, 1289, 33043.0, 343.0, 34403108, 404928, 84961145]}, {"name": "Iran", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1706559, 8554.0, 60867, 81.0, 1456759, 7409.0, 188933.0, 3811, 20141.0, 718.0, 11274630, 133067, 84729135]}, {"name": "Indonesia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1392945, 6389.0, 37757, 210.0, 1210877, 7496.0, 144311.0, -1, 5056.0, 137.0, 11266592, 40894, 275506383]}, {"name": "Israel", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [808262, 3671.0, 5933, 18.0, 764445, 3087.0, 37884.0, 664, 87878.0, 645.0, 12581283, 1367889, 9197590]}, {"name": "Iraq", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y":
"type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [2162001, 7307.0, 53252, 131.0, 1956591, 5051.0, 152158.0, 3525, 47537.0, 1171.0, 7791570, 171318, 45480270]}, {"name": "Peru", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [1380023, 5556.0, 48163, 190.0, 1288067, 5839.0, 43793.0, 2192, 41459.0, 1447.0, 7986252, 239927, 33286198]}, {"name": "Chile", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [864064, 3531.0, 21182, 19.0, 814088, 4147.0, 28794.0, 1839, 44936.0, 1102.0, 9819159, 510649, 19228797]}, {"name": "Ecuador", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [295114, 496.0, 16069, 26.0, 256009, -1.0, 23036.0, 529, 16555.0, 901.0, 1043263, 58524, 17826293]}, {"name": "Bolivia", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [254736, 463.0, 11845, 22.0, 199000, 764.0, 43891.0, 71, 21621.0, 1005.0, 764495, 64887, 11782012]}, {"name": "Paraguay", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [171985, 2125.0, 3360, 17.0, 142893, 1211.0, 25732.0, 324, 23912.0, 467.0, 786625, 109367, 7192549]}, {"name": "Venezuela", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Recovered", "New Recovered", "Active Cases", "Serious/Critical", "Tot Cases/1M", "Deaths/1M", "Total Tests", "Tests/1M", "Population"], "y": [143321, 547.0, 1399, 8.0, 135389, 550.0, 6533.0, 139, 5050.0, 49.0, 2962352, 104380, 28380376]}, {"name": "Uruguay", "type": "bar", "visible": false, "x": ["Total Cases", "New Cases", "Total Deaths", "New Deaths", "Total Re ...

# %%
bar_list = []
for i in country_df.index:
    bar_list.append(go.Bar(name=country_df['Country'][i], y=[country_df['Total Cases'][i]]))
    
fig = go.Figure(data=bar_list)
fig.update_layout(title={'text': 'Stacked Bar Chart of All Countries COVID-19 Cases on %s' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, barmode='stack', height=1200)
fig.show()
# Out:
# <div>                            <div id="3184fe35-5e79-4fb2-b44c-c1c6bae45297" class="plotly-graph-div" style="height:1200px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3184fe35-5e79-4fb2-b44c-c1c6bae45297")) {                    Plotly.newPlot(                        "3184fe35-5e79-4fb2-b44c-c1c6bae45297",                        [{"name": "USA", "type": "bar", "y": [29801506]}, {"name": "India", "type": "bar", "y": [11261470]}, {"name": "Brazil", "type": "bar", "y": [11125017]}, {"name": "Russia", "type": "bar", "y": [4342474]}, {"name": "UK", "type": "bar", "y": [4228998]}, {"name": "France", "type": "bar", "y": [3932862]}, {"name": "Spain", "type": "bar", "y": [3164983]}, {"name": "Italy", "type": "bar", "y": [3101093]}, {"name": "Turkey", "type": "bar", "y": [2807387]}, {"name": "Germany", "type": "bar", "y": [2520609]}, {"name": "Colombia", "type": "bar", "y": [2282372]}, {"name": "Argentina", "type": "bar", "y": [2162001]}, {"name": "Mexico", "type": "bar", "y": [2130477]}, {"name": "Poland", "type": "bar", "y": [1811036]}, {"name": "Iran", "type": "bar", "y": [1706559]}, {"name": "South Africa", "type": "bar", "y": [1522697]}, {"name": "Ukraine", "type": "bar", "y": [1410061]}, {"name": "Indonesia", "type": "bar", "y": [1392945]}, {"name": "Peru", "type": "bar", "y": [1380023]}, {"name": "Czechia", "type": "bar", "y": [1335815]}, {"name": "Netherlands", "type": "bar", "y": [1128202]}, {"name": "Canada", "type": "bar", "y": [893518]}, {"name": "Chile", "type": "bar", "y": [864064]}, {"name": "Romania", "type": "bar", "y": [835552]}, {"name": "Portugal", "type": "bar", "y": [811306]}, {"name": "Israel", "type": "bar", "y": [808262]}, {"name": "Belgium", "type": "bar", "y": [789008]}, {"name": "Iraq", "type": "bar", "y": [735626]}, {"name": "Sweden", "type": "bar", "y": [695975]}, {"name": "Philippines", "type": "bar", "y": [600428]}, {"name": "Pakistan", "type": "bar", "y": [593453]}, {"name": "Switzerland", "type": "bar", "y": [566412]}, {"name": "Bangladesh", "type": "bar", "y": [552087]}, {"name": "Serbia", "type": "bar", "y": [494106]}, {"name": "Morocco", "type": "bar", "y": [486833]}, {"name": "Austria", "type": "bar", "y": [479391]}, {"name": "Hungary", "type": "bar", "y": [475207]}, {"name": "Jordan", "type": "bar", "y": [442202]}, {"name": "Japan", "type": "bar", "y": [440671]}, {"name": "UAE", "type": "bar", "y": [415705]}, {"name": "Lebanon", "type": "bar", "y": [401826]}, {"name": "Saudi Arabia", "type": "bar", "y": [380572]}, {"name": "Panama", "type": "bar", "y": [345759]}, {"name": "Slovakia", "type": "bar", "y": [325993]}, {"name": "Malaysia", "type": "bar", "y": [316269]}, {"name": "Belarus", "type": "bar", "y": [297514]}, {"name": "Ecuador", "type": "bar", "y": [295114]}, {"name": "Nepal", "type": "bar", "y": [274869]}, {"name": "Georgia", "type": "bar", "y": [273137]}, {"name": "Bulgaria", "type": "bar", "y": [266805]}, {"name": "Bolivia", "type": "bar", "y": [254736]}, {"name": "Croatia", "type": "bar", "y": [247099]}, {"name": "Dominican Republic", "type": "bar", "y": [243778]}, {"name": "Tunisia", "type": "bar", "y": [238613]}, {"name": "Azerbaijan", "type": "bar", "y": [237260]}, {"name": "Ireland", "type": "bar", "y": [223957]}, {"name": "Kazakhstan", "type": "bar", "y": [219325]}, {"name": "Denmark", "type": "bar", "y": [215791]}, {"name": "Greece", "type": "bar", "y": [209462]}, {"name": "Costa Rica", "type": "bar", "y": [207832]}, {"name": "Kuwait", "type": "bar", "y": [203055]}, {"name": "Lithuania", "type": "bar", "y": [202900]}, {"name": "Palestine", "type": "bar", "y": [200382]}, {"name": "Moldova", "type": "bar", "y": [196475]}, {"name": "Slovenia", "type": "bar", "y": [196421]}, {"name": "Egypt", "type": "bar", "y": [187716]}, {"name": "Guatemala", "type": "bar", "y": [179563]}, {"name": "Armen ...

# %%
bar = go.Bar(x=country_df['Country'], y=country_df['Total Cases'], marker=dict(color=df['Total Cases'], colorscale='Reds', showscale=True))
fig = go.Figure(data=[bar])
fig.update_layout(title={'text': 'Number of COVID Cases by Country on %s, log scale' % yesterday_str, 'x': 0.5,
                         'xanchor': 'center', 'font': {'size': 20}}, yaxis_type="log", xaxis_tickangle=-90)
# Out:
# <div>                            <div id="3c8e4a23-475d-49ef-a6e7-51cce970ee65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c8e4a23-475d-49ef-a6e7-51cce970ee65")) {                    Plotly.newPlot(                        "3c8e4a23-475d-49ef-a6e7-51cce970ee65",                        [{"marker": {"color": [118146596, 29801506, 11261470, 11125017, 4342474, 4228998, 3932862, 3164983, 3101093, 2807387, 2520609, 2282372, 2162001, 2130477, 1811036, 1706559, 1522697, 1410061, 1392945, 1380023, 1335815, 1128202, 893518, 864064, 835552, 811306, 808262, 789008, 735626, 695975, 600428, 593453, 566412, 552087, 494106, 486833, 479391, 475207, 442202, 440671, 415705, 401826, 380572, 345759, 325993, 316269, 297514, 295114, 274869, 273137, 266805, 254736, 247099, 243778, 238613